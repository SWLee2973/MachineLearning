# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import pickle
import numpy as np
import matplotlib.pyplot as plt
from collections import OrderedDict
from common.layers import *
from common.gradient import numerical_gradient
from common.util import shuffle_dataset
from common.trainer import Trainer
from dataset.mnist import load_mnist

class SimpleConvNet:
    def __init__(self, input_dim=(1, 28, 28), 
                 conv_param_1={'filter_num':20, 'filter_size':5, 'pad':1, 'stride':1},
                 conv_param_2={'filter_num':40, 'filter_size':5, 'pad':1, 'stride':1},
                 hidden_size=100, output_size=10):
        
        pre_node_nums = np.array([1*5*5, 20*5*5, 40*5*5, hidden_size])
        weight_init_scales = np.sqrt(2.0 / pre_node_nums)
        
        self.params = {}
        pre_channel_num = input_dim[0]
        for idx, conv_param in enumerate([conv_param_1, conv_param_2]):
            self.params['W' + str(idx+1)] = weight_init_scales[idx] * np.random.randn(conv_param['filter_num'], pre_channel_num, conv_param['filter_size'], conv_param['filter_size'])
            self.params['b' + str(idx+1)] = np.zeros(conv_param['filter_num'])
            pre_channel_num = conv_param['filter_num']
        self.params['W3'] = weight_init_scales[2] * np.random.randn(40*5*5, hidden_size)
        self.params['b3'] = np.zeros(hidden_size)
        self.params['W4'] = weight_init_scales[3] * np.random.randn(hidden_size, output_size)
        self.params['b4'] = np.zeros(output_size)
        
        # 계층 생성===========
        self.layers = []
        self.layers.append(Convolution(self.params['W1'], self.params['b1'], 
                           conv_param_1['stride'], conv_param_1['pad']))
        self.layers.append(Relu())
        self.layers.append(Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(Convolution(self.params['W2'], self.params['b2'], 
                           conv_param_2['stride'], conv_param_2['pad']))
        self.layers.append(Relu())
        self.layers.append(Pooling(pool_h=2, pool_w=2, stride=2))
        self.layers.append(Affine(self.params['W3'], self.params['b3']))
        self.layers.append(Relu())
        self.layers.append(Dropout(0.5))
        self.layers.append(Affine(self.params['W4'], self.params['b4']))
        self.layers.append(Dropout(0.5))
        
        self.last_layer = SoftmaxWithLoss()
        
    def predict(self, x, train_flg=False):
        for layer in self.layers:
            if isinstance(layer, Dropout):
                x = layer.forward(x, train_flg)
            else:
                x = layer.forward(x)

        return x

    def loss(self, x, t):
        y = self.predict(x, train_flg=True)
        return self.last_layer.forward(y, t)

    def accuracy(self, x, t, batch_size=100):
        if t.ndim != 1 : t = np.argmax(t, axis=1)
        
        acc = 0.0
        
        for i in range(int(x.shape[0] / batch_size)):
            tx = x[i*batch_size:(i+1)*batch_size]
            tt = t[i*batch_size:(i+1)*batch_size]
            y = self.predict(tx)
            y = np.argmax(y, axis=1)
            acc += np.sum(y == tt) 
        
        return acc / x.shape[0]

    def gradient(self, x, t):
        # forward
        self.loss(x, t)

        # backward
        dout = 1
        dout = self.last_layer.backward(dout)

        tmp_layers = self.layers.copy()
        tmp_layers.reverse()
        for layer in tmp_layers:
            dout = layer.backward(dout)

        # 결과 저장
        grads = {}
        for i, layer_idx in enumerate((0, 3, 6, 9)):
            grads['W' + str(i+1)] = self.layers[layer_idx].dW
            grads['b' + str(i+1)] = self.layers[layer_idx].db

        return grads
        
    def save_params(self, file_name="params.pkl"):
        params = {}
        for key, val in self.params.items():
            params[key] = val
        with open(file_name, 'wb') as f:
            pickle.dump(params, f)

    def load_params(self, file_name="params.pkl"):
        with open(file_name, 'rb') as f:
            params = pickle.load(f)
        for key, val in params.items():
            self.params[key] = val

        for i, key in enumerate(0, 3, 6, 9):
            self.layers[layer_idx].W = self.params['W' + str(i+1)]
            self.layers[layer_idx].b = self.params['b' + str(i+1)]

# %%
def cross_validation(x_train, t_train, N):
    v_r = 1/N
    v_n = int(x_train.shape[0] * v_r)
    lr_list = []
    optimization_trial = 5
    max_acc = 0
    selected_lr = 0
    def __train(lr, epochs=10):
            network = SimpleConvNet()
                        
            trainer = Trainer(network, x_t, t_t, x_v, t_v,
                  epochs=epochs, mini_batch_size=1000,
                  optimizer='Adam', optimizer_param={'lr': lr},
                  evaluate_sample_num_per_epoch=1000)
            
            trainer.train()

            return trainer.test_acc_list, trainer.train_acc_list
    
    for j in range(optimization_trial):
         # 탐색한 하이퍼파라미터의 범위 지정===============
        lr = 10 ** np.random.uniform(-3, -2)
        lr_list.append(lr)
        # ================================================
    print("lr_list:" + str(lr_list))
    print("=====================================================")
    for k in range(optimization_trial):
        print("lr = {}".format(lr_list[k]))
        val_acc = []
        
        for i in range(N):
            print("-----------------------------------------------------")
            print("Data {}/{}".format(i+1, N))
            print("-----------------------------------------------------")
            x_v = x_train[i*v_n:(i+1)*v_n]
            t_v = t_train[i*v_n:(i+1)*v_n]
            x_t = np.array(list(x_train[:i*v_n])+list(x_train[(i+1)*v_n:]))
            t_t = np.array(list(t_train[:i*v_n])+list(t_train[(i+1)*v_n:]))
                       
            val_acc_list, train_acc_list = __train(lr_list[k])
            
            print("val acc:" + str(val_acc_list[-1]))
            val_acc.append(val_acc_list[-1])
            
        val_t = np.array(val_acc)
            
        print("-----------------------------------------------------")
        print(val_acc)
        print("lr:" + str(lr_list[k]) + " | accuracy average:" + str(val_t.mean()))
        print("-----------------------------------------------------")
        if max_acc < val_t.mean():
            max_acc = val_t.mean()
            selected_lr = lr_list[k]
    print("=====================================================")
    print("lr:" + str(selected_lr) + " | acc:" + str(max_acc))
    print("=====================================================")

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(flatten = False)

# %%
x_train, t_train = shuffle_dataset(x_train, t_train)

# %%
x_train, t_train = x_train[:5000], t_train[:5000]

# %%
cross_validation(x_train, t_train, 5)
# Out:
# lr_list:[0.0017702595551351487, 0.008182457454720574, 0.0014616910952868916, 0.0035785153684761667, 0.003802650387151003]
# =====================================================
# lr = 0.0017702595551351487
# -----------------------------------------------------
# Data 1/5
# -----------------------------------------------------
# === epoch:1, train acc:0.131, test acc:0.103 ===
# === epoch:2, train acc:0.687, test acc:0.654 ===
# === epoch:3, train acc:0.758, test acc:0.725 ===
# === epoch:4, train acc:0.803, test acc:0.776 ===
# === epoch:5, train acc:0.843, test acc:0.838 ===
# === epoch:6, train acc:0.884, test acc:0.872 ===
# === epoch:7, train acc:0.896, test acc:0.879 ===
# === epoch:8, train acc:0.904, test acc:0.898 ===
# === epoch:9, train acc:0.927, test acc:0.905 ===
# === epoch:10, train acc:0.931, test acc:0.915 ===
# =============== Final Test Accuracy ===============
# test acc:0.923
# val acc:0.915
# -----------------------------------------------------
# Data 2/5
# -----------------------------------------------------
# === epoch:1, train acc:0.184, test acc:0.189 ===
# === epoch:2, train acc:0.687, test acc:0.665 ===
# === epoch:3, train acc:0.788, test acc:0.796 ===
# === epoch:4, train acc:0.841, test acc:0.84 ===
# === epoch:5, train acc:0.872, test acc:0.872 ===
# === epoch:6, train acc:0.892, test acc:0.882 ===
# === epoch:7, train acc:0.903, test acc:0.896 ===
# === epoch:8, train acc:0.917, test acc:0.914 ===
# === epoch:9, train acc:0.932, test acc:0.921 ===
# === epoch:10, train acc:0.94, test acc:0.94 ===
# =============== Final Test Accuracy ===============
# test acc:0.939
# val acc:0.94
# -----------------------------------------------------
# Data 3/5
# -----------------------------------------------------
# === epoch:1, train acc:0.154, test acc:0.177 ===
# === epoch:2, train acc:0.579, test acc:0.55 ===
# === epoch:3, train acc:0.789, test acc:0.737 ===
# === epoch:4, train acc:0.813, test acc:0.772 ===
# === epoch:5, train acc:0.847, test acc:0.792 ===
# === epoch:6, train acc:0.881, test acc:0.836 ===
# === epoch:7, train acc:0.911, test acc:0.857 ===
# === epoch:8, train acc:0.917, test acc:0.873 ===
# === epoch:9, train acc:0.925, test acc:0.888 ===
# === epoch:10, train acc:0.939, test acc:0.904 ===
# =============== Final Test Accuracy ===============
# test acc:0.907
# val acc:0.904
# -----------------------------------------------------
# Data 4/5
# -----------------------------------------------------
# === epoch:1, train acc:0.219, test acc:0.227 ===
# === epoch:2, train acc:0.748, test acc:0.739 ===
# === epoch:3, train acc:0.826, test acc:0.806 ===
# === epoch:4, train acc:0.869, test acc:0.841 ===
# === epoch:5, train acc:0.896, test acc:0.879 ===
# === epoch:6, train acc:0.911, test acc:0.893 ===
# === epoch:7, train acc:0.922, test acc:0.908 ===
# === epoch:8, train acc:0.935, test acc:0.911 ===
# === epoch:9, train acc:0.943, test acc:0.935 ===
# === epoch:10, train acc:0.948, test acc:0.929 ===
# =============== Final Test Accuracy ===============
# test acc:0.939
# val acc:0.929
# -----------------------------------------------------
# Data 5/5
# -----------------------------------------------------
# === epoch:1, train acc:0.295, test acc:0.299 ===
# === epoch:2, train acc:0.655, test acc:0.639 ===
# === epoch:3, train acc:0.78, test acc:0.762 ===
# === epoch:4, train acc:0.829, test acc:0.827 ===
# === epoch:5, train acc:0.865, test acc:0.867 ===
# === epoch:6, train acc:0.887, test acc:0.888 ===
# === epoch:7, train acc:0.924, test acc:0.914 ===
# === epoch:8, train acc:0.927, test acc:0.923 ===
# === epoch:9, train acc:0.936, test acc:0.92 ===
# === epoch:10, train acc:0.934, test acc:0.924 ===
# =============== Final Test Accuracy ===============
# test acc:0.927
# val acc:0.924
# -----------------------------------------------------
# [0.915, 0.94, 0.904, 0.929, 0.924]
# lr:0.0017702595551351487 | accuracy average:0.9224
# -----------------------------------------------------
# lr = 0.008182457454720574
# -----------------------------------------------------
# Data 1/5
# -----------------------------------------------------
# === epoch:1, train acc:0.079, test acc:0.111 ===
# === epoch:2, train acc:0.493, test acc:0.468 ===
# === epoch:3, train acc:0.68, test acc:0.66 ===
# === epoch:4, train acc:0.815, test acc:0.795 ===
# === epoch:5, train acc:0.882, test acc:0.867 ===
# === epoch:6, train acc:0.92, test acc:0.903 ===
# === epoch:7, train acc:0.938, test acc:0.932 ===
# === epoch:8, train acc:0.952, test acc:0.935 ===
# === epoch:9, train acc:0.961, test acc:0.945 ===
# === epoch:10, train acc:0.956, test acc:0.95 ===
# =============== Final Test Accuracy ===============
# test acc:0.952
# val acc:0.95
# -----------------------------------------------------
# Data 2/5
# -----------------------------------------------------
# === epoch:1, train acc:0.105, test acc:0.099 ===
# === epoch:2, train acc:0.687, test acc:0.693 ===
# === epoch:3, train acc:0.848, test acc:0.854 ===
# === epoch:4, train acc:0.905, test acc:0.901 ===
# === epoch:5, train acc:0.934, test acc:0.932 ===
# === epoch:6, train acc:0.959, test acc:0.956 ===
# === epoch:7, train acc:0.959, test acc:0.955 ===
# === epoch:8, train acc:0.969, test acc:0.975 ===
# === epoch:9, train acc:0.976, test acc:0.975 ===
# === epoch:10, train acc:0.975, test acc:0.973 ===
# =============== Final Test Accuracy ===============
# test acc:0.981
# val acc:0.973
# -----------------------------------------------------
# Data 3/5
# -----------------------------------------------------
# === epoch:1, train acc:0.254, test acc:0.229 ===
# === epoch:2, train acc:0.687, test acc:0.674 ===
# === epoch:3, train acc:0.829, test acc:0.805 ===
# === epoch:4, train acc:0.884, test acc:0.846 ===
# === epoch:5, train acc:0.93, test acc:0.881 ===
# === epoch:6, train acc:0.94, test acc:0.917 ===
# === epoch:7, train acc:0.955, test acc:0.937 ===
# === epoch:8, train acc:0.959, test acc:0.941 ===
# === epoch:9, train acc:0.97, test acc:0.942 ===
# === epoch:10, train acc:0.971, test acc:0.954 ===
# =============== Final Test Accuracy ===============
# test acc:0.952
# val acc:0.954
# -----------------------------------------------------
# Data 4/5
# -----------------------------------------------------
# === epoch:1, train acc:0.206, test acc:0.19 ===
# === epoch:2, train acc:0.521, test acc:0.516 ===
# === epoch:3, train acc:0.824, test acc:0.788 ===
# === epoch:4, train acc:0.858, test acc:0.822 ===
# === epoch:5, train acc:0.914, test acc:0.887 ===
# === epoch:6, train acc:0.932, test acc:0.921 ===
# === epoch:7, train acc:0.956, test acc:0.931 ===
# === epoch:8, train acc:0.962, test acc:0.943 ===
# === epoch:9, train acc:0.966, test acc:0.951 ===
# === epoch:10, train acc:0.975, test acc:0.958 ===
# =============== Final Test Accuracy ===============
# test acc:0.958
# val acc:0.958
# -----------------------------------------------------
# Data 5/5
# -----------------------------------------------------
# === epoch:1, train acc:0.129, test acc:0.139 ===
# === epoch:2, train acc:0.537, test acc:0.546 ===
# === epoch:3, train acc:0.838, test acc:0.835 ===
# === epoch:4, train acc:0.887, test acc:0.891 ===
# === epoch:5, train acc:0.927, test acc:0.913 ===
# === epoch:6, train acc:0.945, test acc:0.932 ===
# === epoch:7, train acc:0.95, test acc:0.93 ===
# === epoch:8, train acc:0.967, test acc:0.951 ===
# === epoch:9, train acc:0.974, test acc:0.962 ===
# === epoch:10, train acc:0.979, test acc:0.96 ===
# =============== Final Test Accuracy ===============
# test acc:0.961
# val acc:0.96
# -----------------------------------------------------
# [0.95, 0.973, 0.954, 0.958, 0.96]
# lr:0.008182457454720574 | accuracy average:0.959
# -----------------------------------------------------
# lr = 0.0014616910952868916
# -----------------------------------------------------
# Data 1/5
# -----------------------------------------------------
# === epoch:1, train acc:0.284, test acc:0.281 ===
# === epoch:2, train acc:0.583, test acc:0.533 ===
# === epoch:3, train acc:0.733, test acc:0.711 ===
# === epoch:4, train acc:0.827, test acc:0.811 ===
# === epoch:5, train acc:0.857, test acc:0.839 ===
# === epoch:6, train acc:0.874, test acc:0.871 ===
# === epoch:7, train acc:0.904, test acc:0.888 ===
# === epoch:8, train acc:0.91, test acc:0.905 ===
# === epoch:9, train acc:0.928, test acc:0.918 ===
# === epoch:10, train acc:0.928, test acc:0.925 ===
# =============== Final Test Accuracy ===============
# test acc:0.929
# val acc:0.925
# -----------------------------------------------------
# Data 2/5
# -----------------------------------------------------
# === epoch:1, train acc:0.139, test acc:0.147 ===
# === epoch:2, train acc:0.629, test acc:0.597 ===
# === epoch:3, train acc:0.78, test acc:0.781 ===
# === epoch:4, train acc:0.826, test acc:0.837 ===
# === epoch:5, train acc:0.867, test acc:0.868 ===
# === epoch:6, train acc:0.881, test acc:0.87 ===
# === epoch:7, train acc:0.9, test acc:0.889 ===
# === epoch:8, train acc:0.916, test acc:0.904 ===
# === epoch:9, train acc:0.936, test acc:0.913 ===
# === epoch:10, train acc:0.936, test acc:0.919 ===
# =============== Final Test Accuracy ===============
# test acc:0.93
# val acc:0.919
# -----------------------------------------------------
# Data 3/5
# -----------------------------------------------------
# === epoch:1, train acc:0.318, test acc:0.303 ===
# === epoch:2, train acc:0.643, test acc:0.588 ===
# === epoch:3, train acc:0.772, test acc:0.722 ===
# === epoch:4, train acc:0.843, test acc:0.795 ===
# === epoch:5, train acc:0.867, test acc:0.817 ===
# === epoch:6, train acc:0.887, test acc:0.845 ===
# === epoch:7, train acc:0.909, test acc:0.868 ===
# === epoch:8, train acc:0.923, test acc:0.877 ===
# === epoch:9, train acc:0.928, test acc:0.893 ===
# === epoch:10, train acc:0.94, test acc:0.901 ===
# =============== Final Test Accuracy ===============
# test acc:0.907
# val acc:0.901
# -----------------------------------------------------
# Data 4/5
# -----------------------------------------------------
# === epoch:1, train acc:0.313, test acc:0.258 ===
# === epoch:2, train acc:0.63, test acc:0.618 ===
# === epoch:3, train acc:0.737, test acc:0.723 ===
# === epoch:4, train acc:0.773, test acc:0.765 ===
# === epoch:5, train acc:0.818, test acc:0.798 ===
# === epoch:6, train acc:0.846, test acc:0.816 ===
# === epoch:7, train acc:0.884, test acc:0.856 ===
# === epoch:8, train acc:0.899, test acc:0.873 ===
# === epoch:9, train acc:0.91, test acc:0.884 ===
# === epoch:10, train acc:0.93, test acc:0.911 ===
# =============== Final Test Accuracy ===============
# test acc:0.918
# val acc:0.911
# -----------------------------------------------------
# Data 5/5
# -----------------------------------------------------
# === epoch:1, train acc:0.272, test acc:0.265 ===
# === epoch:2, train acc:0.718, test acc:0.698 ===
# === epoch:3, train acc:0.741, test acc:0.752 ===
# === epoch:4, train acc:0.821, test acc:0.82 ===
# === epoch:5, train acc:0.87, test acc:0.862 ===
# === epoch:6, train acc:0.879, test acc:0.881 ===
# === epoch:7, train acc:0.907, test acc:0.891 ===
# === epoch:8, train acc:0.917, test acc:0.899 ===
# === epoch:9, train acc:0.925, test acc:0.916 ===
# === epoch:10, train acc:0.94, test acc:0.919 ===
# =============== Final Test Accuracy ===============
# test acc:0.925
# val acc:0.919
# -----------------------------------------------------
# [0.925, 0.919, 0.901, 0.911, 0.919]
# lr:0.0014616910952868916 | accuracy average:0.915
# -----------------------------------------------------
# lr = 0.0035785153684761667
# -----------------------------------------------------
# Data 1/5
# -----------------------------------------------------
# === epoch:1, train acc:0.177, test acc:0.188 ===
# === epoch:2, train acc:0.732, test acc:0.706 ===
# === epoch:3, train acc:0.842, test acc:0.826 ===
# === epoch:4, train acc:0.87, test acc:0.862 ===
# === epoch:5, train acc:0.898, test acc:0.897 ===
# === epoch:6, train acc:0.935, test acc:0.931 ===
# === epoch:7, train acc:0.942, test acc:0.944 ===
# === epoch:8, train acc:0.954, test acc:0.951 ===
# === epoch:9, train acc:0.956, test acc:0.955 ===
# === epoch:10, train acc:0.971, test acc:0.96 ===
# =============== Final Test Accuracy ===============
# test acc:0.962
# val acc:0.96
# -----------------------------------------------------
# Data 2/5
# -----------------------------------------------------
# === epoch:1, train acc:0.168, test acc:0.167 ===
# === epoch:2, train acc:0.437, test acc:0.469 ===
# === epoch:3, train acc:0.561, test acc:0.573 ===
# === epoch:4, train acc:0.751, test acc:0.736 ===
# === epoch:5, train acc:0.805, test acc:0.808 ===
# === epoch:6, train acc:0.87, test acc:0.86 ===
# === epoch:7, train acc:0.901, test acc:0.895 ===
# === epoch:8, train acc:0.915, test acc:0.907 ===
# === epoch:9, train acc:0.932, test acc:0.924 ===
# === epoch:10, train acc:0.941, test acc:0.931 ===
# =============== Final Test Accuracy ===============
# test acc:0.951
# val acc:0.931
# -----------------------------------------------------
# Data 3/5
# -----------------------------------------------------
# === epoch:1, train acc:0.201, test acc:0.189 ===
# === epoch:2, train acc:0.685, test acc:0.65 ===
# === epoch:3, train acc:0.837, test acc:0.795 ===
# === epoch:4, train acc:0.862, test acc:0.828 ===
# === epoch:5, train acc:0.897, test acc:0.872 ===
# === epoch:6, train acc:0.925, test acc:0.897 ===
# === epoch:7, train acc:0.942, test acc:0.921 ===
# === epoch:8, train acc:0.949, test acc:0.921 ===
# === epoch:9, train acc:0.96, test acc:0.933 ===
# === epoch:10, train acc:0.964, test acc:0.939 ===
# =============== Final Test Accuracy ===============
# test acc:0.934
# val acc:0.939
# -----------------------------------------------------
# Data 4/5
# -----------------------------------------------------
# === epoch:1, train acc:0.18, test acc:0.168 ===
# === epoch:2, train acc:0.619, test acc:0.607 ===
# === epoch:3, train acc:0.805, test acc:0.813 ===
# === epoch:4, train acc:0.854, test acc:0.838 ===
# === epoch:5, train acc:0.894, test acc:0.867 ===
# === epoch:6, train acc:0.925, test acc:0.896 ===
# === epoch:7, train acc:0.94, test acc:0.914 ===
# === epoch:8, train acc:0.95, test acc:0.934 ===
# === epoch:9, train acc:0.959, test acc:0.941 ===
# === epoch:10, train acc:0.959, test acc:0.938 ===
# =============== Final Test Accuracy ===============
# test acc:0.951
# val acc:0.938
# -----------------------------------------------------
# Data 5/5
# -----------------------------------------------------
# === epoch:1, train acc:0.188, test acc:0.199 ===
# === epoch:2, train acc:0.666, test acc:0.649 ===
# === epoch:3, train acc:0.767, test acc:0.778 ===
# === epoch:4, train acc:0.848, test acc:0.856 ===
# === epoch:5, train acc:0.874, test acc:0.872 ===
# === epoch:6, train acc:0.915, test acc:0.908 ===
# === epoch:7, train acc:0.935, test acc:0.912 ===
# === epoch:8, train acc:0.949, test acc:0.93 ===
# === epoch:9, train acc:0.955, test acc:0.929 ===
# === epoch:10, train acc:0.956, test acc:0.932 ===
# =============== Final Test Accuracy ===============
# test acc:0.939
# val acc:0.932
# -----------------------------------------------------
# [0.96, 0.931, 0.939, 0.938, 0.932]
# lr:0.0035785153684761667 | accuracy average:0.9400000000000001
# -----------------------------------------------------
# lr = 0.003802650387151003
# -----------------------------------------------------
# Data 1/5
# -----------------------------------------------------
# === epoch:1, train acc:0.1, test acc:0.114 ===
# === epoch:2, train acc:0.575, test acc:0.536 ===
# === epoch:3, train acc:0.783, test acc:0.759 ===
# === epoch:4, train acc:0.862, test acc:0.849 ===
# === epoch:5, train acc:0.903, test acc:0.892 ===
# === epoch:6, train acc:0.925, test acc:0.926 ===
# === epoch:7, train acc:0.941, test acc:0.934 ===
# === epoch:8, train acc:0.948, test acc:0.95 ===
# === epoch:9, train acc:0.959, test acc:0.959 ===
# === epoch:10, train acc:0.958, test acc:0.955 ===
# =============== Final Test Accuracy ===============
# test acc:0.961
# val acc:0.955
# -----------------------------------------------------
# Data 2/5
# -----------------------------------------------------
# === epoch:1, train acc:0.132, test acc:0.12 ===
# === epoch:2, train acc:0.596, test acc:0.632 ===
# === epoch:3, train acc:0.753, test acc:0.775 ===
# === epoch:4, train acc:0.872, test acc:0.863 ===
# === epoch:5, train acc:0.893, test acc:0.875 ===
# === epoch:6, train acc:0.915, test acc:0.896 ===
# === epoch:7, train acc:0.934, test acc:0.932 ===
# === epoch:8, train acc:0.95, test acc:0.941 ===
# === epoch:9, train acc:0.954, test acc:0.954 ===
# === epoch:10, train acc:0.966, test acc:0.957 ===
# =============== Final Test Accuracy ===============
# test acc:0.96
# val acc:0.957
# -----------------------------------------------------
# Data 3/5
# -----------------------------------------------------
# === epoch:1, train acc:0.172, test acc:0.166 ===
# === epoch:2, train acc:0.629, test acc:0.608 ===
# === epoch:3, train acc:0.826, test acc:0.808 ===
# === epoch:4, train acc:0.896, test acc:0.851 ===
# === epoch:5, train acc:0.908, test acc:0.883 ===
# === epoch:6, train acc:0.941, test acc:0.905 ===
# === epoch:7, train acc:0.95, test acc:0.914 ===
# === epoch:8, train acc:0.962, test acc:0.929 ===
# === epoch:9, train acc:0.966, test acc:0.937 ===
# === epoch:10, train acc:0.966, test acc:0.946 ===
# =============== Final Test Accuracy ===============
# test acc:0.947
# val acc:0.946
# -----------------------------------------------------
# Data 4/5
# -----------------------------------------------------
# === epoch:1, train acc:0.098, test acc:0.107 ===
# === epoch:2, train acc:0.482, test acc:0.505 ===
# === epoch:3, train acc:0.694, test acc:0.702 ===
# === epoch:4, train acc:0.806, test acc:0.794 ===
# === epoch:5, train acc:0.86, test acc:0.837 ===
# === epoch:6, train acc:0.9, test acc:0.878 ===
# === epoch:7, train acc:0.902, test acc:0.892 ===
# === epoch:8, train acc:0.93, test acc:0.908 ===
# === epoch:9, train acc:0.927, test acc:0.911 ===
# === epoch:10, train acc:0.938, test acc:0.925 ===
# =============== Final Test Accuracy ===============
# test acc:0.93
# val acc:0.925
# -----------------------------------------------------
# Data 5/5
# -----------------------------------------------------
# === epoch:1, train acc:0.153, test acc:0.163 ===
# === epoch:2, train acc:0.568, test acc:0.543 ===
# === epoch:3, train acc:0.658, test acc:0.645 ===
# === epoch:4, train acc:0.797, test acc:0.779 ===
# === epoch:5, train acc:0.854, test acc:0.832 ===
# === epoch:6, train acc:0.887, test acc:0.869 ===
# === epoch:7, train acc:0.905, test acc:0.898 ===
# === epoch:8, train acc:0.923, test acc:0.912 ===
# === epoch:9, train acc:0.937, test acc:0.918 ===
# === epoch:10, train acc:0.946, test acc:0.925 ===
# =============== Final Test Accuracy ===============
# test acc:0.931
# val acc:0.925
# -----------------------------------------------------
# [0.955, 0.957, 0.946, 0.925, 0.925]
# lr:0.003802650387151003 | accuracy average:0.9415999999999999
# -----------------------------------------------------
# =====================================================
# lr:0.008182457454720574 | acc:0.959
# =====================================================

# %%
(x_train, t_train), (x_test, t_test) = load_mnist(flatten = False)

# %%
max_epochs = 20

network = SimpleConvNet()
                        
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=max_epochs, mini_batch_size=1000,
                  optimizer='Adam', optimizer_param={'lr': 0.008182457454720574},
                  evaluate_sample_num_per_epoch=1000)

# %%
trainer.train()
# Out:
# === epoch:1, train acc:0.119, test acc:0.1 ===
# === epoch:2, train acc:0.976, test acc:0.976 ===
# === epoch:3, train acc:0.985, test acc:0.984 ===
# === epoch:4, train acc:0.986, test acc:0.985 ===
# === epoch:5, train acc:0.989, test acc:0.987 ===
# === epoch:6, train acc:0.99, test acc:0.985 ===
# === epoch:7, train acc:0.992, test acc:0.99 ===
# === epoch:8, train acc:0.99, test acc:0.988 ===
# === epoch:9, train acc:0.991, test acc:0.988 ===
# === epoch:10, train acc:0.992, test acc:0.991 ===
# === epoch:11, train acc:0.995, test acc:0.989 ===
# === epoch:12, train acc:0.992, test acc:0.992 ===
# === epoch:13, train acc:0.995, test acc:0.989 ===
# === epoch:14, train acc:0.993, test acc:0.989 ===
# === epoch:15, train acc:0.996, test acc:0.992 ===
# === epoch:16, train acc:0.993, test acc:0.985 ===
# === epoch:17, train acc:0.995, test acc:0.987 ===
# === epoch:18, train acc:0.994, test acc:0.992 ===
# === epoch:19, train acc:0.995, test acc:0.991 ===
# === epoch:20, train acc:0.993, test acc:0.989 ===
# =============== Final Test Accuracy ===============
# test acc:0.9916
